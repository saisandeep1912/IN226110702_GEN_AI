# %%
# !pip install -U langchain langchain-core

from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
# Out:
# Requirement already satisfied: langchain in c:\users\saisa\anaconda3\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in c:\users\saisa\anaconda3\lib\site-packages (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\saisa\anaconda3\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\saisa\anaconda3\lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\saisa\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\saisa\anaconda3\lib\site-packages (from langchain-core) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\saisa\anaconda3\lib\site-packages (from langchain-core) (24.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\saisa\anaconda3\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\saisa\anaconda3\lib\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\saisa\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\saisa\anaconda3\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\saisa\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\saisa\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\saisa\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\saisa\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\saisa\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\saisa\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\saisa\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\saisa\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\saisa\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\saisa\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\saisa\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in c:\users\saisa\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.7.0)
# Requirement already satisfied: certifi in c:\users\saisa\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\saisa\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\saisa\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\saisa\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\saisa\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\saisa\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saisa\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saisa\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\saisa\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)

# %% [markdown]
# # Replace Hardcoded Prompts

# %%
# Define template
template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# Function using template
def explain_topic(topic):
    return template_1.format(topic=topic)

# Test
print(explain_topic("Machine Learning"))
# Out:
# Explain Machine Learning in simple terms for beginners

# %% [markdown]
# # Multi-Input Prompt System

# %%
multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test Cases
print(multi_input_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_input_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_input_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# # Prompt Variations Engine

# %%
# Teaching Template
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

# Interview Template
interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

# Storytelling Template
story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

# Run all
topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# # ChatPromptTemplate System

# %%
def get_chat_prompt(role, topic):
    
    if role == "teacher":
        system_message = "You are a helpful teacher who explains concepts clearly."
    elif role == "interviewer":
        system_message = "You are an interviewer asking challenging questions."
    elif role == "motivator":
        system_message = "You are a motivational speaker who inspires learners."
    else:
        system_message = "You are a helpful assistant."

    chat_template = ChatPromptTemplate.from_messages([
        ("system", system_message),
        ("user", "Explain {topic}")
    ])

    return chat_template.format_messages(topic=topic)

# Test
messages = get_chat_prompt("teacher", "Neural Networks")
for msg in messages:
    print(msg)
# Out:
# content='You are a helpful teacher who explains concepts clearly.' additional_kwargs={} response_metadata={}
# content='Explain Neural Networks' additional_kwargs={} response_metadata={}

# %% [markdown]
# # Input Validation Layer

# %%
def validate_inputs(audience, tone):
    
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]
    
    # Default values
    if audience not in valid_audience:
        print("Invalid audience. Defaulting to 'beginner'")
        audience = "beginner"
        
    if tone not in valid_tone:
        print("Invalid tone. Defaulting to 'formal'")
        tone = "formal"
        
    return audience, tone

# Test
print(validate_inputs("kids", "funny"))
# Out:
# Invalid audience. Defaulting to 'beginner'
# Invalid tone. Defaulting to 'formal'
# ('beginner', 'formal')

# %% [markdown]
# # Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):
    
    # Step 1: Validate
    audience, tone = validate_inputs(audience, tone)
    
    # Step 2: Choose template based on style
    if style == "teaching":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} teaching style"
        )
        
    elif style == "interview":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Ask interview questions on {topic} for {audience} in a {tone} tone"
        )
        
    elif style == "storytelling":
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} storytelling style"
        )
        
    else:
        template = PromptTemplate(
            input_variables=["topic", "audience", "tone"],
            template="Explain {topic} for {audience} in a {tone} tone"
        )
    
    return template.format(topic=topic, audience=audience, tone=tone)

# Test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %% [markdown]
# # Template Reusability Test

# %%
# ONE reusable template
reusable_template = PromptTemplate(
    input_variables=["topic", "audience"],
    template="Explain {topic} for {audience}"
)

# 5 different inputs
inputs = [
    {"topic": "AI", "audience": "beginners"},
    {"topic": "Python", "audience": "kids"},
    {"topic": "Data Science", "audience": "students"},
    {"topic": "Deep Learning", "audience": "engineers"},
    {"topic": "Statistics", "audience": "analysts"}
]

for inp in inputs:
    print(reusable_template.format(**inp))
# Out:
# Explain AI for beginners
# Explain Python for kids
# Explain Data Science for students
# Explain Deep Learning for engineers
# Explain Statistics for analysts

# %% [markdown]
# # Final Pipeline Demonstration

# %%
def full_pipeline(topic, audience, tone, style):
    
    # Step 1: Validation
    audience, tone = validate_inputs(audience, tone)
    
    # Step 2: Generate Prompt
    prompt = generate_prompt(topic, audience, tone, style)
    
    return prompt

# Run full pipeline
print(full_pipeline("Machine Learning", "beginner", "fun", "teaching"))
# Out:
# Explain Machine Learning for beginner in a fun teaching style
